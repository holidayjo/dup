# %% [markdown]
# ## 1. Clone yolov9

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 781, done.
# remote: Total 781 (delta 0), reused 0 (delta 0), pack-reused 781 (from 1)
# Receiving objects: 100% (781/781), 3.27 MiB | 15.43 MiB/s, done.
# Resolving deltas: 100% (330/330), done.

# %%
# %cd yolov9/
# Out:
# /media/dad/My_Doc2/Github/yolov9

# %%
path: /media/dad/My_Doc2/Github/data/  # dataset root dir
train: chungmuro_sangsun_PM_rush/train
val: chungmuro_sangsun_PM_rush/val
test: chungmuro_sangsun_PM_rush/test

# Classes
names:
  0: U
  1: D
  2: P
