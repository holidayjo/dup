# %% [markdown]
# # Training code example

# %%
# !python train.py  --cfg cfg/sd_net_2h_6a.yaml --hyp data/hyp.scratch.tiny.yaml --data data/coco.yaml --weights '' --device 0 --batch-size 300 --epochs 300 --name coco_sd_net5_2h_6a

# %% [markdown]
# # Inference example

# %%
# !python detect.py --weights /mnt/Documents/Dad/github/DUP/sd_net/runs/train/udp_sd_net_2h_6a_seed0/weights/last.pt --source /mnt/Documents/Dad/github/DUP/pics --conf 0.1 --name coco_sd_net5_2h_6a_results --img-size 320 --device 0
# Out:
# /bin/bash: /home/hj/anaconda3/envs/hj/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Namespace(weights=['/mnt/Documents/Dad/github/DUP/sd_net/runs/train/udp_sd_net_2h_6a_seed0/weights/last.pt'], source='/mnt/Documents/Dad/github/DUP/pics', img_size=320, conf_thres=0.1, iou_thres=0.45, device='0', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='coco_sd_net5_2h_6a_results', exist_ok=False, no_trace=False)
# YOLOR 🚀 1d968ba3 torch 2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4080, 15926.6875MB)
#
# Fusing layers...
# IDetect.fuse
# Model Summary: 132 layers, 1588064 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %% [markdown]
# # Output

# %%
import cv2
import matplotlib.pyplot as plt
imshow = cv2.imread('runs/detect/coco_sd_net5_2h_6a_results2/4_004410.jpg')
imshow = cv2.cvtColor(imshow, cv2.COLOR_BGR2RGB)
plt.imshow(imshow)
plt.show()
